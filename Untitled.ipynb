# %% [markdown]
# ![image.png](attachment:f2507d1a-971b-4239-baba-7e57f4e11aed.png)

# %% [raw]
# 소스를 밖에서 실행하라는 말임

# %% [markdown]
# ![image.png](attachment:14c3fc0d-89ee-478f-82d8-7b21661e308e.png)
