# %% [markdown]
# ### 20240109 오후 4시 수업

# %% [markdown]
# ![image.png](attachment:baae0dda-2074-4969-94fe-cd8f2738c50f.png)

# %% [raw]
# Class Hello는 설계도 개념(아무것도 못함)
# 객체를 생성한다는 말은 제품을 찍어내는 개념
#
# 변수와 매써드를 사용하려면 객체를 생성해야함 -> Hello h = new Hello();
# 원래는 h.main 이렇게 당겨왔어야함.
#
# 하지만 지금은 객체 생성없이 나옴. ->tomcat이 코드를 직접 치지 않았는데도 객체 생성을 해주었음.

# %% [markdown]
# ![image.png](attachment:39aea8d8-e7d8-4957-ba5b-bb39fe0dc80c.png)

# %% [markdown]
# ![image.png](attachment:40f01d3c-d1d6-43e7-aea1-53801fb8819d.png)

# %% [markdown]
# ![image.png](attachment:86223c94-cc2e-4fa3-8b7b-f0e322b62a3d.png)

# %% [raw]
# integer안에있는 parseint를 숫자 형태로 바꿔서 yyyy에 집어넣는 것

# %% [markdown]
# ### 20240109 오후 5시 수업

# %% [markdown]
# ![image.png](attachment:f3453db9-139f-4f6f-a17c-184c2f00aae2.png)

# %% [raw]
# 결과 : 한글깨져서 이상하게 나오는 것

# %% [raw]
# args[0] = 2021 / args[1] = 10 / args[2] = 1

# %% [markdown]
# # 1. 관심사의 분리, MVC 패턴

# %% [markdown]
# ## 1.1. 관심사의 분리

# %% [markdown]
# ### 1.1.1. 솔리드 5대 설계원칙

# %% [markdown]
# #### 1.1.1.1. SRP(단일책임의 원칙 : Single Responsibility Principle)

# %% [markdown]
# #### 1.1.1.2. OCP(개방폐쇄의 원칙 : Open Close Principle)

# %% [markdown]
# #### 1.1.1.3. LSP(리스코브 치환의 원칙 : The Liskov Substitution Principle)

# %% [markdown]
# #### 1.1.1.4. ISP(인터페이스 분리의 원칙 : Interface Segregation Principle)

# %% [markdown]
# #### 1.1.1.5. DIP(의존성역전의 원칙 : Dependency Inversion Principle)

# %% [markdown]
# ## 1.2. MVC패턴

# %% [markdown]
# 출력부(View)와 처리부(Controller)의 상호작용(Model)

# %% [markdown]
# ## URL맵핑

# %% [markdown]
# ### 1. exact mapping : 정확히 일치
# - 정확히 일치 = 우선순위 1
# - URL pattern : /login/hello.do

# %% [markdown]
# ### 2. path mapping
# - 우선순위 2
# - URL pattern : login/*

# %% [markdown]
# ### 3. extension mapping
# -  우선순위 3
# - URL pattern : *.do

# %% [markdown]
# ### 4. dafault mapping
# - 우선순위 4
# - URL pattern : /

# %% [markdown]
# ## EL표현식

# %%
<%=%> ${}

# %% [markdown]
# ## JAVA UI

# %% [raw]
# 1. AWT
# 2. Swing
# 3. JavaFX

# %% [markdown]
# #### 1. Java 환경설정

# %% [raw]
# 적절한 버전의 javaFX를 다운받아 C:\Program Files\Java\javafx-sdk-XX.x.XX 경로에 압축을 푼다

# %% [markdown]
# #### 2. Scene Builder 설치

# %% [raw]
# C:\Program Files\Java\javafx-sdk-XX.x.XX\SceneBuilder 경로에 설치한다.

# %% [markdown]
# #### 3. e(fx)clipse 설치

# %% [raw]
# 이클립스에서 [Help]-[Eclipse Marketplace]를 선택한 후 'javafx'로 검색하여, e(fx)clipse 플러그인이 검색되면 [Install] 버튼을 눌러 설치한다.

# %% [markdown]
# #### 4

# %% [markdown]
# ![image.png](attachment:0cb09a05-c0b0-4d4a-b806-7a718e0850b0.png)

# %% [raw]
# Eclipse에서 [Window]-[Preferences] 선택, 왼쪽의 JavaFX 선택 후, SceneBuilder 실행파일 경로의 SceneBuilder.exe 선택

# %% [markdown]
# ![image.png](attachment:bff26e4d-0cf0-460f-9835-c8e730ec37d3.png)

# %% [raw]
# JavaFX 11 + SDK는 C:\Program Files\Java\jdk-17\javafx-sdk-21.0.2\lib 을 선택 - [파일선택]

# %% [markdown]
# #### 5.JavaFX 모듈 참조

# %% [markdown]
# ![image.png](attachment:8e94fdfc-420c-41c4-b4bc-58129317a548.png)

# %%
프로젝트 선택, 오른쪽 버튼 -> Buildpath -> [Liber]

# %% [markdown]
# ![image.png](attachment:633b01fe-00f1-43d8-9b3f-7888127aadfe.png)

# %% [markdown]
# ![image.png](attachment:192fdb41-9000-4841-8d40-ba9d30785e06.png)

# %% [markdown]
# ![image.png](attachment:de2b8cb6-4154-45f2-b5d9-be4b0a0d4768.png)

# %% [markdown]
# ![image.png](attachment:ddf73861-8763-4420-a608-5220218d879e.png)

# %% [markdown]
# ![image.png](attachment:13b4686c-2945-434b-9c21-6565022b1ad4.png)
